# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, PROJECT_ROOT)

print("Project root added:", PROJECT_ROOT)
# Out:
# Project root added: C:\Users\Shash\RL_Hospital_Project

# %%
import os
print(os.listdir(PROJECT_ROOT))
# Out:
# ['data', 'models', 'notebooks', 'results', 'utils']

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import pandas as pd
from utils.hospital_env import HospitalEnv

data = pd.read_csv("../data/synthetic_hospital_data.csv")

env = HospitalEnv(data)
state = env.reset()

done = False
total_reward = 0

while not done:
    action = 1
    state, reward, done = env.step(action)
    total_reward += reward

print("Episode finished. Total reward:", total_reward)
# Out:
# Episode finished. Total reward: 3365
